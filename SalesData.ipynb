# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"D:\python projects\sales data1\9. Sales-Data-Analysis.csv")
data
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0       10452  07-11-2022               Fries   3.49    573.07       Online
# 1       10453  07-11-2022           Beverages   2.95    745.76       Online
# 2       10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3       10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4       10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# ..        ...         ...                 ...    ...       ...           ...
# 249     10709  28-12-2022       Sides & Other   4.99    200.40   Drive-thru
# 250     10710  29-12-2022             Burgers  12.99    754.43   Drive-thru
# 251     10711  29-12-2022  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712  29-12-2022               Fries   3.49    630.37   Drive-thru
# 253     10713  29-12-2022           Beverages   2.95    677.97   Drive-thru
#
#     Payment Method             Manager    City
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 18.0+ KB

# %%
data.loc[0]
# Out:
# Order ID                     10452
# Date                    07-11-2022
# Product                      Fries
# Price                         3.49
# Quantity                    573.07
# Purchase Type              Online
# Payment Method           Gift Card
# Manager           Tom      Jackson
# City                        London
# Name: 0, dtype: object

# %%
# to change the 1st row into column headings we'll use data.columns = data.loc[0]

# %%
data.head()
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon
# 3    Credit Card       Walter Muller  Berlin
# 4    Credit Card       Walter Muller  Berlin

# %%
# to drop any row --  data.drop(0) --0 for 1st row

# %%
data.Manager
# Out:
# 0        Tom      Jackson
# 1             Pablo Perez
# 2           Joao    Silva
# 3           Walter Muller
# 4           Walter Muller
#               ...
# 249         Walter Muller
# 250         Walter Muller
# 251         Walter Muller
# 252         Walter Muller
# 253         Walter Muller
# Name: Manager, Length: 254, dtype: object

# %%
data.Manager.unique()
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
data['Manager'] = data['Manager'].str.strip().str.replace(r'\s+', ' ',regex = True)

# %%
data.head(20)
# Out:
#     Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0      10452  07-11-2022               Fries   3.49    573.07       Online
# 1      10453  07-11-2022           Beverages   2.95    745.76       Online
# 2      10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3      10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4      10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# 5      10457  08-11-2022               Fries   3.49    573.07     In-store
# 6      10459  08-11-2022       Sides & Other   4.99    200.40     In-store
# 7      10460  09-11-2022             Burgers  12.99    554.27     In-store
# 8      10461  09-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# 9      10462  09-11-2022               Fries   3.49    573.07     In-store
# 10     10463  09-11-2022           Beverages   2.95    677.97     In-store
# ...

# %%
data['Manager'].nunique()
# Out:
# 5

# %%
data['Manager'].unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %% [markdown]
# # Removing Duplicates

# %%
data.head()
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method        Manager    City
# 0      Gift Card    Tom Jackson  London
# 1      Gift Card    Pablo Perez  Madrid
# 2      Gift Card     Joao Silva  Lisbon
# 3    Credit Card  Walter Muller  Berlin
# 4    Credit Card  Walter Muller  Berlin

# %%
data.describe(include = 'all')
# Out:
#             Order ID        Date  Product       Price    Quantity  \
# count     254.000000         254      254  254.000000  254.000000
# unique           NaN          53        5         NaN         NaN
# top              NaN  03-12-2022  Burgers         NaN         NaN
# freq             NaN           5       52         NaN         NaN
# mean    10584.133858         NaN      NaN    7.102323  460.611457
# std        75.889181         NaN      NaN    4.341855  214.888699
# min     10452.000000         NaN      NaN    2.950000  200.400000
# 25%     10520.250000         NaN      NaN    3.490000  201.010000
# 50%     10583.500000         NaN      NaN    4.990000  538.880000
# 75%     10649.750000         NaN      NaN    9.950000  677.440000
# max     10713.000000         NaN      NaN   29.050000  754.430000
#
#        Purchase Type Payment Method      Manager    City
# count            254            254          254     254
# unique             3              3            5       5
# ...

# %%
data[data.duplicated()]    #to show all the duplicate records
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data.drop_duplicates(inplace = True)

# %%
data[data['Order ID'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %% [markdown]
# # converting data type of each columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 18.0+ KB

# %%
# to change data type data.Quantity.astype(float).to make it permanent data.Quantity = data.Quantity.astype(float)

# %%
# to roundoff values of Quantity tabel --data.Quantity = data.Quantity.astype(round)

# %%
data.Quantity = data.Quantity.astype(int)

# %%
data.Date =  pd.to_datetime(data['Date'], format='%d-%m-%Y')

# %%
data.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    datetime64[ns]
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    int32
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(1), object(5)
# memory usage: 17.0+ KB

# %% [markdown]
# # Q1 Most Preffered payment method?

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries   3.49       573       Online
# 1     10453 2022-11-07           Beverages   2.95       745       Online
# 2     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 3     10455 2022-11-08             Burgers  12.99       569     In-store
# 4     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
#   Payment Method        Manager    City
# 0      Gift Card    Tom Jackson  London
# 1      Gift Card    Pablo Perez  Madrid
# 2      Gift Card     Joao Silva  Lisbon
# 3    Credit Card  Walter Muller  Berlin
# 4    Credit Card  Walter Muller  Berlin

# %%
data['Payment Method'].unique()
# Out:
# array([' Gift Card', ' Credit Card', ' Cash'], dtype=object)

# %%
data['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    120
# Cash            76
# Gift Card       58
# Name: count, dtype: int64

# %%
data['Payment Method'].value_counts(normalize = True)*100
# Out:
# Payment Method
# Credit Card    47.244094
# Cash           29.921260
# Gift Card      22.834646
# Name: proportion, dtype: float64

# %%
data['Payment Method'].value_counts().plot.barh()
# Out:
# <Axes: ylabel='Payment Method'>

# %% [markdown]
# # Q2 Most selling product .)by quantity .)by revenue

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries   3.49       573       Online
# 1     10453 2022-11-07           Beverages   2.95       745       Online
# 2     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 3     10455 2022-11-08             Burgers  12.99       569     In-store
# 4     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
#   Payment Method        Manager    City
# 0      Gift Card    Tom Jackson  London
# 1      Gift Card    Pablo Perez  Madrid
# 2      Gift Card     Joao Silva  Lisbon
# 3    Credit Card  Walter Muller  Berlin
# 4    Credit Card  Walter Muller  Berlin

# %%
data['Product'].value_counts()
# Out:
# Product
# Burgers               52
# Chicken Sandwiches    52
# Fries                 51
# Beverages             50
# Sides & Other         49
# Name: count, dtype: int64

# %%
data.groupby('Product')['Quantity'].sum().sort_values()
# Out:
# Product
# Sides & Other          9800
# Chicken Sandwiches    11132
# Burgers               28996
# Fries                 32016
# Beverages             34938
# Name: Quantity, dtype: int32

# %%
most_quantity = data.groupby('Product')['Quantity'].sum().sort_values()
most_quantity
# Out:
# Product
# Sides & Other          9800
# Chicken Sandwiches    11132
# Burgers               28996
# Fries                 32016
# Beverages             34938
# Name: Quantity, dtype: int32

# %%
type(most_quantity)
# Out:
# pandas.core.series.Series

# %%
#to make the type in dataframe format we'll use reset.index()

# %%
most_quantity = most_quantity.reset_index()
most_quantity
# Out:
#               Product  Quantity
# 0       Sides & Other      9800
# 1  Chicken Sandwiches     11132
# 2             Burgers     28996
# 3               Fries     32016
# 4           Beverages     34938

# %%
plt.figure(figsize = (9,4))
plt.bar(most_quantity['Product'],most_quantity['Quantity']);

# %% [markdown]
# # by revenue

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries   3.49       573       Online
# 1     10453 2022-11-07           Beverages   2.95       745       Online
# 2     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 3     10455 2022-11-08             Burgers  12.99       569     In-store
# 4     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
#   Payment Method        Manager    City
# 0      Gift Card    Tom Jackson  London
# 1      Gift Card    Pablo Perez  Madrid
# 2      Gift Card     Joao Silva  Lisbon
# 3    Credit Card  Walter Muller  Berlin
# 4    Credit Card  Walter Muller  Berlin

# %%
data['Revenue'] = data['Price']*data['Quantity']

# %%
data
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0       10452 2022-11-07               Fries   3.49       573       Online
# 1       10453 2022-11-07           Beverages   2.95       745       Online
# 2       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 3       10455 2022-11-08             Burgers  12.99       569     In-store
# 4       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 249     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 250     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 251     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 252     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 253     10713 2022-12-29           Beverages   2.95       677   Drive-thru
#
#     Payment Method        Manager    City  Revenue
# ...

# %%
most_revenue = data.groupby('Product')['Revenue'].sum().sort_values()
most_revenue
# Out:
# Product
# Sides & Other          48902.00
# Beverages             103067.10
# Chicken Sandwiches    114602.50
# Fries                 125602.14
# Burgers               376658.04
# Name: Revenue, dtype: float64

# %%
most_revenue= most_revenue.reset_index()
most_revenue
# Out:
#               Product    Revenue
# 0       Sides & Other   48902.00
# 1           Beverages  103067.10
# 2  Chicken Sandwiches  114602.50
# 3               Fries  125602.14
# 4             Burgers  376658.04

# %%
plt.figure(figsize = (9,4))
plt.bar(most_revenue['Product'],most_revenue['Revenue']);

# %% [markdown]
# # Q.3) Which city had maximum revenue , or , Which Manager earned maximum revenue ?

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries   3.49       573       Online
# 1     10453 2022-11-07           Beverages   2.95       745       Online
# 2     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 3     10455 2022-11-08             Burgers  12.99       569     In-store
# 4     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
#   Payment Method        Manager    City  Revenue
# 0      Gift Card    Tom Jackson  London  1999.77
# 1      Gift Card    Pablo Perez  Madrid  2197.75
# 2      Gift Card     Joao Silva  Lisbon   998.00
# 3    Credit Card  Walter Muller  Berlin  7391.31
# 4    Credit Card  Walter Muller  Berlin  1999.95

# %%
Max_rev_city = data.groupby('City')['Revenue'].sum().sort_values(ascending = False)
Max_rev_city
# Out:
# City
# Lisbon    241509.38
# London    211001.83
# Madrid    136098.22
# Berlin    100492.73
# Paris      79729.62
# Name: Revenue, dtype: float64

# %%
Max_rev_city.reset_index()
# Out:
#      City    Revenue
# 0  Lisbon  241509.38
# 1  London  211001.83
# 2  Madrid  136098.22
# 3  Berlin  100492.73
# 4   Paris   79729.62

# %%
max_revenue_manager = data.groupby('Manager')['Revenue'].sum().sort_values(ascending = False)
max_revenue_manager
# Out:
# Manager
# Joao Silva       241509.38
# Tom Jackson      211001.83
# Pablo Perez      136098.22
# Walter Muller    100492.73
# Remy Monet        79729.62
# Name: Revenue, dtype: float64

# %%
type(max_revenue_manager)
# Out:
# pandas.core.series.Series

# %%
max_revenue_manager = max_revenue_manager.reset_index()
max_revenue_manager
# Out:
#          Manager    Revenue
# 0     Joao Silva  241509.38
# 1    Tom Jackson  211001.83
# 2    Pablo Perez  136098.22
# 3  Walter Muller  100492.73
# 4     Remy Monet   79729.62

# %%
type(max_revenue_manager)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Q.4) Date wise revenue.

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries   3.49       573       Online
# 1     10453 2022-11-07           Beverages   2.95       745       Online
# 2     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 3     10455 2022-11-08             Burgers  12.99       569     In-store
# 4     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
#   Payment Method        Manager    City  Revenue
# 0      Gift Card    Tom Jackson  London  1999.77
# 1      Gift Card    Pablo Perez  Madrid  2197.75
# 2      Gift Card     Joao Silva  Lisbon   998.00
# 3    Credit Card  Walter Muller  Berlin  7391.31
# 4    Credit Card  Walter Muller  Berlin  1999.95

# %%
data.plot('Date','Revenue',color = 'red')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Q.5) Average Revenue.

# %%
data['Revenue'].mean()
# Out:
# 3026.8967716535435

# %% [markdown]
# # Q.6) Average Revenue of November & December month.

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries   3.49       573       Online
# 1     10453 2022-11-07           Beverages   2.95       745       Online
# 2     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 3     10455 2022-11-08             Burgers  12.99       569     In-store
# 4     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
#   Payment Method        Manager    City  Revenue  Month
# 0      Gift Card    Tom Jackson  London  1999.77     11
# 1      Gift Card    Pablo Perez  Madrid  2197.75     11
# 2      Gift Card     Joao Silva  Lisbon   998.00     11
# 3    Credit Card  Walter Muller  Berlin  7391.31     11
# 4    Credit Card  Walter Muller  Berlin  1999.95     11

# %%
data['Month']=data['Date'].dt.month

# %%
m11 = data[data['Month']==11]
m11
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0       10452 2022-11-07               Fries   3.49       573       Online
# 1       10453 2022-11-07           Beverages   2.95       745       Online
# 2       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 3       10455 2022-11-08             Burgers  12.99       569     In-store
# 4       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 108     10568 2022-11-30           Beverages   2.95       677       Online
# 109     10569 2022-11-30       Sides & Other   4.99       200       Online
# 127     10537 2022-11-24               Fries   3.49       630   Drive-thru
# 128     10538 2022-11-24           Beverages   2.95       745   Drive-thru
# 129     10539 2022-11-24       Sides & Other   4.99       200   Drive-thru
#
#     Payment Method        Manager    City  Revenue  Month
# ...

# %%
m11.Revenue.mean()
# Out:
# 2936.6534513274337

# %%
data['Month'] = data['Date'].dt.month

# %%
data.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries   3.49       573       Online
# 1     10453 2022-11-07           Beverages   2.95       745       Online
# 2     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 3     10455 2022-11-08             Burgers  12.99       569     In-store
# 4     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
#   Payment Method        Manager    City  Revenue  Month
# 0      Gift Card    Tom Jackson  London  1999.77     11
# 1      Gift Card    Pablo Perez  Madrid  2197.75     11
# 2      Gift Card     Joao Silva  Lisbon   998.00     11
# 3    Credit Card  Walter Muller  Berlin  7391.31     11
# 4    Credit Card  Walter Muller  Berlin  1999.95     11

# %%
m12 = data[data['Month'] ==12]
m12
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 110     10570 2022-12-01             Burgers  12.99       492       Online
# 111     10571 2022-12-01  Chicken Sandwiches   9.95       201       Online
# 112     10572 2022-12-01               Fries   3.49       573       Online
# 113     10573 2022-12-01           Beverages   2.95       677       Online
# 114     10574 2022-12-01       Sides & Other   4.99       200       Online
# ..        ...        ...                 ...    ...       ...           ...
# 249     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 250     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 251     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 252     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 253     10713 2022-12-29           Beverages   2.95       677   Drive-thru
#
#     Payment Method        Manager    City  Revenue  Month
# ...

# %%
m12.Revenue.mean()
# Out:
# 3099.2194326241133

# %% [markdown]
# # Q.7) Standard Deviation of Revenue and Quantity ?

# %%
data['Quantity'].std()
# Out:
# 214.69197583196447

# %%
data['Revenue'].std()
# Out:
# 2418.1931282105456

# %% [markdown]
# # Q.8) Variance of Revenue and Quantity ?

# %%
data['Revenue'].var()
# Out:
# 5847658.005324705

# %%
data['Quantity'].var()
# Out:
# 46092.64448663282

# %% [markdown]
# # Q.9) Is revenue increasing or decreasing over time?

# %%
m11 = data[data['Month']==11]
m11
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0       10452 2022-11-07               Fries   3.49       573       Online
# 1       10453 2022-11-07           Beverages   2.95       745       Online
# 2       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 3       10455 2022-11-08             Burgers  12.99       569     In-store
# 4       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 108     10568 2022-11-30           Beverages   2.95       677       Online
# 109     10569 2022-11-30       Sides & Other   4.99       200       Online
# 127     10537 2022-11-24               Fries   3.49       630   Drive-thru
# 128     10538 2022-11-24           Beverages   2.95       745   Drive-thru
# 129     10539 2022-11-24       Sides & Other   4.99       200   Drive-thru
#
#     Payment Method        Manager    City  Revenue  Month
# ...

# %%
m11['Revenue'].sum()
# Out:
# 331841.84

# %%
m12 = data[data['Month']==12]
m12
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 110     10570 2022-12-01             Burgers  12.99       492       Online
# 111     10571 2022-12-01  Chicken Sandwiches   9.95       201       Online
# 112     10572 2022-12-01               Fries   3.49       573       Online
# 113     10573 2022-12-01           Beverages   2.95       677       Online
# 114     10574 2022-12-01       Sides & Other   4.99       200       Online
# ..        ...        ...                 ...    ...       ...           ...
# 249     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 250     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 251     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 252     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 253     10713 2022-12-29           Beverages   2.95       677   Drive-thru
#
#     Payment Method        Manager    City  Revenue  Month
# ...

# %%
m12['Revenue'].sum()
# Out:
# 436989.94

# %% [markdown]
# # Q.10) Average 'Quantity Sold' & 'Average Revenue' for each product ?

# %%
data.groupby('Product')['Revenue'].mean()
# Out:
# Product
# Beverages             2061.342000
# Burgers               7243.423846
# Chicken Sandwiches    2203.894231
# Fries                 2462.787059
# Sides & Other          998.000000
# Name: Revenue, dtype: float64

# %%
data.groupby('Product')['Quantity'].mean()
# Out:
# Product
# Beverages             698.760000
# Burgers               557.615385
# Chicken Sandwiches    214.076923
# Fries                 627.764706
# Sides & Other         200.000000
# Name: Quantity, dtype: float64

# %%
# if u want to check together

# %%
data.groupby('Product')[['Quantity','Revenue']].agg({'Quantity':'mean','Revenue':'mean'})
# Out:
#                       Quantity      Revenue
# Product
# Beverages           698.760000  2061.342000
# Burgers             557.615385  7243.423846
# Chicken Sandwiches  214.076923  2203.894231
# Fries               627.764706  2462.787059
# Sides & Other       200.000000   998.000000
